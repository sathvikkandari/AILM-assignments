# %% [markdown]
# > untitled3-1
# > February 19, 2024
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>}</p>
# </blockquote></th>
# <th><blockquote>
# <p>'A': {'B': {'D': {'H': -1, 'I': 4}, 'E': {'J': 2, 'K': 6}}, 'C':
# {'F': {'L': -3, 'M': -5}, 'G': {'N': 0, 'O': 7}}<br />
# }</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[2\]: tree = {
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> min_max(node,
# maximizing_player=<strong>True</strong>):<br />
# <strong>if</strong> type(node) <strong>is not</strong> dict:<br />
# <strong>return</strong> node<br />
# <strong>if</strong> maximizing_player:<br />
# <strong>return</strong> max(min_max(child, <strong>False</strong>)
# <strong>for</strong> child <strong>in</strong> node.values())
# <strong>else</strong>:<br />
# <strong>return</strong> min(min_max(child, <strong>True</strong>)
# <strong>for</strong> child <strong>in</strong> node.values()) result =
# min_max(tree['A'])<br />
# print(f"The value of the root node A after applying Min-Max is
# <strong>{</strong>result<strong>}</strong>")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > The value of the root node A after applying Min-Max is 4
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'A': {'B': {'D': {'H': -1, 'I': 4}, 'E': {'J': 2, 'K': 6}}, 'C':
# {'F': {'L': -3, 'M': -5}, 'G': {'N': 0, 'O': 7}} }<br />
# }<br />
# <strong>def</strong> alpha_beta(node, alpha, beta,
# maximizing_player=<strong>True</strong>): <strong>if</strong> type(node)
# <strong>is not</strong> dict:<br />
# <strong>return</strong> node<br />
# <strong>if</strong> maximizing_player:<br />
# max_val = float('-inf')<br />
# <strong>for</strong> child <strong>in</strong> node.values():<br />
# value = alpha_beta(child, alpha, beta, <strong>False</strong>) max_val =
# max(max_val, value)<br />
# alpha = max(alpha, value)<br />
# <strong>if</strong> beta &lt;= alpha:<br />
# <strong>break</strong><br />
# <strong>return</strong> max_val<br />
# <strong>else</strong>:<br />
# min_val = float('inf')<br />
# <strong>for</strong> child <strong>in</strong> node.values():</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[3\]: tree = {
#
# 1
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>value = alpha_beta(child, alpha, beta, <strong>True</strong>)<br />
# min_val = min(min_val, value)<br />
# beta = min(beta, value)<br />
# <strong>if</strong> beta &lt;= alpha:<br />
# <strong>break</strong><br />
# <strong>return</strong> min_val<br />
# result = alpha_beta(tree['A'], float('-inf'), float('inf'))<br />
# print(f"The value of the root node A after applying Alpha-Beta pruning
# is␣</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > ↪**{**result**}**")
#
# The value of the root node A after applying Alpha-Beta pruning is 4
#
# 2
