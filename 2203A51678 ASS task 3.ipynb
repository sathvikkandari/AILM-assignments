# %%
#Assignment 3
import pandas as pd
pd.read_csv("/content/drive/MyDrive/marks.csv")
# Out:
#    slno      name  marks
# 0     1  raviteja     90
# 1     2      moiz     96
# 2     3   sathvik     92
# 3     4  vaninath     87
# 4     5   pritham     77
# 5     6    nithin     40
# 6     7    nikhil     80
# 7     8   dheeraj     86

# %%
pd.read_excel("/content/drive/MyDrive/marks1.xlsx")
# Out:
#    slno      name  marks
# 0     1  raviteja     90
# 1     2      moiz     96
# 2     3   sathvik     92
# 3     4  vaninath     87
# 4     5   pritham     77
# 5     6    nithin     40
# 6     7    nikhil     80
# 7     8   dheeraj     86
